# %% [markdown]
# Investigación sobre los factores que influyen en la expansión urbana en México
#
# Análisis de los datos para 135 ciudades para analizar las siguientes correlaciones:
#
# - ¿Existe una correlación entre los subsidios federales y la expansión urbana?
# - ¿Existe una correlación entre la tasa de motorización y la expansión urbana?
# - ¿Existe una correlación entre aumento en el ingreso y la expansión urbana?
# - ¿Existe una correlación entre restricciones a la densidad y la expansión urbana?
# - ¿Existe una correlación entre el decrecimiento del tamaño familiar y la expansión urbana?
#
# Datos históricos: 1980, 2000, 2005 y 2010
#
# Objetivo: analizar la tendencia histórica lo más posible.
#
#
# El análisis nos permitirá no es solo comprobar la correlación sino identificar que tan poderosas son las variables sobre las que sí podemos tener control: __subsidios federales y restricciones a la densidad.

# %%
from __future__ import print_function
__author__ = 'mo'
import pylab as pl
import numpy as np
# %pylab inline

import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
import geopandas as gp
import json

import statsmodels.formula.api as smf
from statsmodels.graphics.api import abline_plot 
from pandas.stats.plm import PanelOLS

import sklearn.cluster
from sklearn import mixture
from PIL import Image
from scipy.misc import imread
from scipy.cluster.vq import kmeans2
#import mplleaflet
#import shapely.geometry as geom
import networkx as nx
import xlrd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
base = pd.read_csv('basedatos7.csv')
base.columns
# Out:
# Index([u'orden reporte', u'zm_flag', u'nombre_zm', u'nombre_zm_match_sina',
#        u'nombre_zm_match', u'estado', u'clasificacion', u'pob_1980',
#        u'den_1980', u'pob_2000', u'den_2000', u'pob_2005', u'den_2005',
#        u'pob_2010', u'den_2010', u'den_change', u'cambio_pob', u'area_1980',
#        u'area_2000', u'area_2005', u'area_2010', u'cambio_area', u'sub_2015',
#        u'sub_2010', u'sub_2010_nueva_eco', u'normativa',
#        u'remuneraciones_1980', u'remuneraciones_2000', u'remunera_2009',
#        u'remunera_2014', u'autos_2014', u'autos_1980', u'tasamoto_1980',
#        u'autos_2000', u'tasamoto_2000', u'autos_2005', u'tasamoto_2005',
#        u'autos_2010', u'tasamoto_2010', u'tam_fam_1980', u'tam_fam_2000',
#        u'tam_fam_2005', u'tam_fam_2010', u'cambio_fam', u'PIB_2010'],
#       dtype='object')

# %%
base
# Out:
#      orden reporte  zm_flag                        nombre_zm  \
# 0               14        0                   Aguascalientes
# 1                6        0                          Tijuana
# 2               51        0                        Ensenada
# 3               13        0                         Mexicali
# 4               59        0                          La Paz
# 5               81        0                  Cabo San Lucas
# 6              102        0               San Jos_ del Cabo
# 7               57        0                        Campeche
# 8               66        0               Ciudad del Carmen
# 9               24        0                 Tuxtla Guti_rrez
# 10              58        0  Tapachula de C�rdova y Ord�_ez
# 11              70        0      San Crist�bal de las Casas
# 12              98        0            Comit�n de Dom�nguez
# 13               8        0                           Ju�rez
# 14              18        0                        Chihuahua
# 15              86        0                        Delicias
# 16              87        0                      Cuauht_moc
# 17              94        0               Hidalgo del Parral
# 18             128        0             Nuevas Casas Grandes
# 19               1        1                  Valle de M_xico
# 20               9        0                        La Laguna
# 21              19        0                         Saltillo
# 22              45        1               Monclova-Frontera
# 23              65        1                  Piedras Negras
# 24              80        0                    Ciudad Acu_a
# 25             130        0                          Sabinas
# 26              44        1         Colima-Villa de �lvarez
# 27              74        1                         Tecom�n
# 2             NaN         4.150         3.660          3.41    0.931694
# 3             NaN         4.110         3.670          3.69    1.005450
# 4             NaN         3.800         3.650          3.47    0.950685
# 5             NaN         4.050         3.760          3.57    0.949468
# 6             NaN         4.010         3.760          3.57    0.949468
# 7             NaN         4.100         4.000          3.56    0.890000
# 8             NaN         4.090         3.830          3.73    0.973890
# 9             NaN         4.480         3.870          3.84    0.992248
# 10            NaN         4.180         4.060          3.72    0.916256
# 11            NaN         4.130         4.400          4.33    0.984091
# 12            NaN         4.430         4.140          4.01    0.968599
# 13            NaN         4.410         3.500          3.69    1.054286
# 14            NaN         4.440         3.600          3.47    0.963889
# 15            NaN         4.400         3.660          3.47    0.948087
# 16            NaN         4.500         3.560          3.48    0.977528
# 17            NaN         5.670         3.790          3.69    0.973615
# 18            NaN         4.500         3.690          3.47    0.940379
# 19            NaN         4.310         3.670          3.58    0.975477
# 20            NaN         4.210         4.035          3.91    0.969021
# 21            NaN         4.510         4.000          3.87    0.967500
# 22            NaN         3.800         3.840          3.68    0.958333
# 23            NaN         4.130         3.790          3.72    0.981530
# 24            NaN         3.600         3.990          3.73    0.934837
# 25            NaN         3.870         3.700          3.55    0.959459
# 26            NaN         4.345         3.630          3.44    0.947658
# 27            NaN         4.535         3.910          3.90    0.997442
# 28            NaN         4.110         3.630          3.50    0.964187
# 29            NaN         4.540         4.040          3.89    0.962871
# ..            ...           ...           ...           ...         ...
# 105           NaN           NaN         3.840          3.55    0.924479
# 106           NaN           NaN         3.800          3.69    0.971053
# 107           NaN           NaN         4.020          3.85    0.957711
# 108           NaN           NaN         3.850          3.86    1.002597
# 109           NaN           NaN         3.820          3.67    0.960733
# 110           NaN           NaN         3.870          3.63    0.937984
# 111           NaN           NaN         3.790          3.56    0.939314
# 112           NaN           NaN         4.260          3.84    0.901408
# 113           NaN           NaN         3.520          3.62    1.028409
# 114           NaN           NaN         3.780          3.68    0.973545
# 115           NaN           NaN         3.920          3.81    0.971939
# 116           NaN           NaN         3.800          3.75    0.986842
# 117           NaN           NaN         3.550          3.46    0.974648
# 118           NaN           NaN         3.580          3.45    0.963687
# 119           NaN           NaN         4.000          3.87    0.978481
# 120           NaN           NaN         4.620          4.34    0.939394
# 121           NaN           NaN         3.460          3.38    0.976879
# 122           NaN           NaN         3.630          3.57    0.983471
# 123           NaN           NaN         3.700          3.72    1.005405
# 124           NaN           NaN         3.560          3.56    1.000000
# 125           NaN           NaN         3.740          3.48    0.930481
# 126           NaN           NaN         3.580          3.45    0.963687
# 127           NaN           NaN         3.750          3.60    0.960000
# 128           NaN           NaN         3.950          3.79    0.959494
# 129           NaN           NaN         3.760          3.65    0.970745
# 130           NaN           NaN         3.800          3.63    0.955263
# 131           NaN           NaN         4.120          3.92    0.951456
# 132           NaN           NaN         3.740          3.58    0.957219
# 133           NaN           NaN         4.070          3.81    0.936118
# 134           NaN           NaN         4.150          4.00    0.963855
#
#          PIB_2010
# 0             NaN
# 1    2.714916e+08
# 2    3.096071e+07
# 3             NaN
# 4    1.252739e+07
# 5    1.815599e+08
# 6    2.382692e+07
# 7             NaN
# 8             NaN
# 9    1.693817e+07
# 10   3.795200e+07
# 11   1.302708e+08
# 12   3.415521e+09
# 13   5.576653e+08
# 14            NaN
# 15            NaN
# 16            NaN
# 17   1.145577e+08
# 18            NaN
# 19            NaN
# 20   1.393611e+08
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25   3.500660e+08
# 26   4.035028e+07
# 27            NaN
# 28            NaN
# 29            NaN
# ..            ...
# 105  1.691135e+08
# 106  1.468995e+08
# 107           NaN
# 108  3.417661e+06
# 109           NaN
# 110  6.977226e+06
# 111  2.882805e+07
# 112           NaN
# 113           NaN
# 114           NaN
# 115  3.519996e+07
# 116           NaN
# 117           NaN
# 118  9.108866e+07
# 119           NaN
# 120  1.059565e+07
# 121           NaN
# 122           NaN
# 123  4.030066e+07
# 124           NaN
# 125  2.125232e+08
# 126  2.669131e+07
# 127  1.839161e+07
# 128           NaN
# 129  1.602520e+07
# 130  3.381281e+08
# 131  3.694863e+07
# 132  1.075792e+09
# 133           NaN
# 134  1.147014e+07
#
# [135 rows x 45 columns]

# %%
#setting up columns as variables to look at
#area in ha
area2010 = base['area_2010']
area2005 = base.area_2005
area2000 = base.area_2000
area1980 = base.area_1980

#population
pop2010 = base['pob_2010']
pop2005 = base.pob_2005
pop2000 = base.pob_2000
pop1980 = base.pob_1980

#rates of change
carea = base.cambio_area
cpop = base.cambio_pob

#motorization rate
moto1980 = base.tasamoto_1980
moto2000 = base.tasamoto_2000
moto2005 = base.tasamoto_2005
moto2010 = base.tasamoto_2010

#subisides
sub2010 = base.sub_2010
sub2010new = base.sub_2010_nueva_eco
#Family size
fam2010 = base.tam_fam_2010
fam2005 = base.tam_fam_2005
fam2000 = base.tam_fam_2000

#income
rem2009 = base.remunera_2009

# %%
#area2010

# %% [markdown]
# # Exploratory analysis
# ## City areas heavily skewed to smaller sizes

# %%
print("% change area 1980-2010", carea.mean())
print("% change pop 1980-2010",cpop.mean())
# Out:
# % change area 1980-2010 11.5377777778
# % change pop 1980-2010 4.40962962963

# %%
print("area 2010 min", area2010.min())
print("area 2010 max", area2010.max())
# Out:
# area 2010 min 841
# area 2010 max 185291

# %% [markdown]
# ### Dropping Mexico City as this made the graph less readable
#
# #### Looking at maximum areas to know how long to make the axis for the graph below

# %%
fig = pl.figure(figsize=(10,10))
bins = np.arange(800, 70000, 2500)
area2010s = area2010.drop([19])
#area2010s.size
area2010s.groupby(pd.cut(area2010s, bins)).agg([count_nonzero]).plot(kind='bar')

# %%
print("area 2005 min", area2005.min())
print("area 2005 max", area2005.max())
area2005s = area2010.drop([19])
print("area 2005 max sin ZMVM", area2005s.max())
# Out:
# area 2005 min 689
# area 2005 max 174616
# area 2005 max sin ZMVM 63018

# %%
fig = pl.figure(figsize=(10,10))
bins = np.arange(600, 70000, 2500)
area2005.groupby(pd.cut(area2005, bins)).agg([count_nonzero]).plot(kind='bar')

# %%
print("area 2000 min", area2000.min())
print("area 2000 max", area2000.max())
area2000s = area2000.drop([19])
print("area 2000 max sin ZMVM", area2000s.max())
# Out:
# area 2000 min 607
# area 2000 max 167081
# area 2000 max sin ZMVM 56619

# %%
fig = pl.figure(figsize=(10,10))
bins = np.arange(600, 70000, 2500)
area2000s.groupby(pd.cut(area2000s, bins)).agg([count_nonzero]).plot(kind='bar')

# %%
#area2000s.sort_values()
#we see that 54, 74, 86 are over 48, so we exclude these to get a better sense of distribution
area2000sm = area2000s.drop([54, 74, 86])
area2000sm.size
area2000sm.max()
# Out:
# 29928

# %%
fig = pl.figure(figsize=(10,10))
bins = np.arange(600, 30000, 2500)
area2000sm.groupby(pd.cut(area2000sm, bins)).agg([count_nonzero]).plot(kind='bar')

# %% [markdown]
# # Looking at trends and correlations
#
# ### City area with family size

# %%
#area and family size, I only have family size for 2010, 2005 and 2000
fig = pl.figure(figsize=(20,20))

pl.subplot(3,2,1)
pl.loglog(area2010, fam2010, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Family Size', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w Family Size 2010')

pl.subplot(3,2,2)
pl.loglog(area2005, fam2005, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Family Size', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w Family Size 2005')

pl.subplot(3,2,3)
pl.loglog(area2000, fam2000, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Family Size', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w Family Size 2000')

# %%
#area and family size, for 2000-2010, dropping Mexico City (Valle de Mexico)
fam2010s = fam2010.drop([19])
fam2005s = fam2005.drop([19])
fam2000s = fam2000.drop([19])


fig = pl.figure(figsize=(20,20))

pl.subplot(3,2,1)
pl.loglog(area2010s, fam2010s, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Family Size', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w Family Size 2010')

pl.subplot(3,2,2)
pl.loglog(area2005s, fam2005s, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Family Size', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w Family Size 2005')

pl.subplot(3,2,3)
pl.loglog(area2000s, fam2000s, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Family Size', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w Family Size 2000')

# %% [markdown]
# ### City area with motorization rate

# %%
fig = pl.figure(figsize=(20,20))

pl.subplot(3,2,1)
pl.loglog(area2010, moto2010, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Motorization rate', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w Motorization rate 2010')

pl.subplot(3,2,2)
pl.loglog(area2005, moto2005, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Motorization Rate', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w Motorization rate 2005')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-3af9499af579> in <module>()
#       9
#      10 pl.subplot(3,2,2)
# ---> 11 pl.loglog(area2005, moto2005, '.')
#      12 pl.xlabel('City Area', fontsize=17)
#      13 pl.ylabel('Motorization Rate', fontsize=17)
#
# /Users/mariaortiz/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in loglog(*args, **kwargs)
#    3037         ax.hold(hold)
#    3038     try:
# -> 3039         ret = ax.loglog(*args, **kwargs)
#    3040     finally:
#    3041         ax.hold(washold)
#
# /Users/mariaortiz/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in loglog(self, *args, **kwargs)
#    1560         b = self._hold
#    1561         self._hold = True  # we've already processed the hold
# -> 1562         l = self.plot(*args, **kwargs)
#    1563         self._hold = b  # restore the hold
#    1564
#
# /Users/mariaortiz/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /Users/mariaortiz/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1423
#    1424         for line in self._get_lines(*args, **kwargs):
# -> 1425             self.add_line(line)
#    1426             lines.append(line)
#    1427
#
# /Users/mariaortiz/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in add_line(self, line)
#    1706             line.set_clip_path(self.patch)
#    1707
# -> 1708         self._update_line_limits(line)
#    1709         if not line.get_label():
#    1710             line.set_label('_line%d' % len(self.lines))
#
# /Users/mariaortiz/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _update_line_limits(self, line)
#    1728         Figures out the data limit of the given line, updating self.dataLim.
#    1729         """
# -> 1730         path = line.get_path()
#    1731         if path.vertices.size == 0:
#    1732             return
#
# /Users/mariaortiz/anaconda/lib/python2.7/site-packages/matplotlib/lines.pyc in get_path(self)
#     923         """
#     924         if self._invalidy or self._invalidx:
# --> 925             self.recache()
#     926         return self._path
#     927
#
# /Users/mariaortiz/anaconda/lib/python2.7/site-packages/matplotlib/lines.pyc in recache(self, always)
#     619                 y = ma.asarray(yconv, np.float_).filled(np.nan)
#     620             else:
# --> 621                 y = np.asarray(yconv, np.float_)
#     622             y = y.ravel()
#     623         else:
#
# /Users/mariaortiz/anaconda/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     472
#     473     """
# --> 474     return array(a, dtype, copy=False, order=order)
#     475
#     476 def asanyarray(a, dtype=None, order=None):
#
# ValueError: could not convert string to float: -

# %% [markdown]
# ### City area with population
# ##### Not very interesting...direct correlation as expected, more disperse and flat in 1980

# %%
fig = pl.figure(figsize=(20,20))

pl.subplot(3,2,1)
pl.loglog(area2010, pop2010, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Pop', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w pop 2010')

pl.subplot(3,2,2)
pl.loglog(area2005, pop2005, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Pop', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w pop 2005')

pl.subplot(3,2,3)
pl.loglog(area2000, pop2000, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Pop', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w pop 2000')

pl.subplot(3,2,4)
pl.loglog(area1980, pop1980, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Pop', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w pop 1980')

# %% [markdown]
# ### Area with subsidies

# %%
fig = pl.figure(figsize=(20,20))

pl.subplot(3,2,1)
pl.loglog(area2010, sub2010, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Subsidies 2010', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w subsidies 2010')

pl.subplot(3,2,2)
pl.loglog(area2010, sub2010new, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Subsidies 2010 for new construction', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w subsidies 2010 for new construction')

# %% [markdown]
# ## Dropping CDMX

# %%
sub2010s = sub2010.drop([19])
sub2010news = sub2010new.drop([19])

fig = pl.figure(figsize=(20,20))

pl.subplot(3,2,1)
pl.loglog(area2010s, sub2010s, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Subsidies 2010', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w subsidies 2010')

pl.subplot(3,2,2)
pl.loglog(area2010s, sub2010news, '.')
pl.xlabel('City Area', fontsize=17)
pl.ylabel('Subsidies 2010 for new construction', fontsize=17)
pl.legend(loc = 0, fontsize = 10)
pl.title('Area w subsidies 2010 for new construction')

# %% [markdown]
# # Simple linear regression

# %%
import statsmodels.formula.api as smf
from statsmodels.graphics.api import abline_plot

# %%
#Independent variable is area for 2010, dependent on motorization rate, family size, income and subsidies
d = {'area2010': area2010, 'moto2010': moto2010, 'fam2010': fam2010, 'rem2009': rem2009, 'sub2010': sub2010}
# Run regression and print summary
mod = smf.ols(formula='area2010 ~ moto2010 + fam2010 + rem2009 + sub2010', data = d).fit()
print(mod.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               area2010   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     6.129
# Date:                Thu, 05 May 2016   Prob (F-statistic):           0.000151
# Time:                        10:43:36   Log-Likelihood:                -1492.1
# No. Observations:                 134   AIC:                             2994.
# Df Residuals:                     129   BIC:                             3009.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   -817.9957   4707.448     -0.174      0.862     -1.01e+04  8495.805
# moto2010      -9.6138      5.759     -1.669      0.097       -21.009     1.781
# fam2010        0.1678      7.138      0.024      0.981       -13.955    14.291
# rem2009      134.7617     49.743      2.709      0.008        36.344   233.179
# sub2010     9.941e-05    3.5e-05      2.844      0.005      3.03e-05     0.000
# ==============================================================================
# Omnibus:                      224.741   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24267.851
# Skew:                           7.203   Prob(JB):                         0.00
# Kurtosis:                      67.335   Cond. No.                     1.59e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.59e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               area2010   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     6.129
# Date:                Mon, 02 May 2016   Prob (F-statistic):           0.000151
# Time:                        20:31:10   Log-Likelihood:                -1492.1
# No. Observations:                 134   AIC:                             2994.
# Df Residuals:                     129   BIC:                             3009.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   -817.9957   4707.448     -0.174      0.862     -1.01e+04  8495.805
# moto2010      -9.6138      5.759     -1.669      0.097       -21.009     1.781
# fam2010        0.1678      7.138      0.024      0.981       -13.955    14.291
# rem2009      134.7617     49.743      2.709      0.008        36.344   233.179
# sub2010     9.941e-05    3.5e-05      2.844      0.005      3.03e-05     0.000
# ==============================================================================
# Omnibus:                      224.741   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24267.851
# Skew:                           7.203   Prob(JB):                         0.00
# Kurtosis:                      67.335   Cond. No.                     1.59e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.59e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Interpretation: R2 is .16, this only explains 16% of the variablity in area size, so it is not a great model.
#
# ### Family size and motorization rate are not statistically significant, so we will remove them in the next model

# %%
#Independent variable is area for 2010, income and subsidies
d = {'area2010': area2010, 'rem2009': rem2009, 'sub2010': sub2010}
# Run regression and print summary
mod2 = smf.ols(formula='area2010 ~ rem2009 + sub2010', data = d).fit()
print(mod2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               area2010   R-squared:                       0.142
# Model:                            OLS   Adj. R-squared:                  0.129
# Method:                 Least Squares   F-statistic:                     10.96
# Date:                Thu, 05 May 2016   Prob (F-statistic):           3.94e-05
# Time:                        10:43:44   Log-Likelihood:                -1504.2
# No. Observations:                 135   AIC:                             3014.
# Df Residuals:                     132   BIC:                             3023.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -4921.5625   3952.010     -1.245      0.215     -1.27e+04  2895.904
# rem2009      140.0936     49.270      2.843      0.005        42.633   237.554
# sub2010        0.0001   3.48e-05      3.015      0.003       3.6e-05     0.000
# ==============================================================================
# Omnibus:                      225.261   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23950.438
# Skew:                           7.166   Prob(JB):                         0.00
# Kurtosis:                      66.659   Cond. No.                     1.33e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
mod2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               area2010   R-squared:                       0.142
# Model:                            OLS   Adj. R-squared:                  0.129
# Method:                 Least Squares   F-statistic:                     10.96
# Date:                Thu, 05 May 2016   Prob (F-statistic):           3.94e-05
# Time:                        10:43:50   Log-Likelihood:                -1504.2
# No. Observations:                 135   AIC:                             3014.
# Df Residuals:                     132   BIC:                             3023.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -4921.5625   3952.010     -1.245      0.215     -1.27e+04  2895.904
# rem2009      140.0936     49.270      2.843      0.005        42.633   237.554
# sub2010        0.0001   3.48e-05      3.015      0.003       3.6e-05     0.000
# ==============================================================================
# Omnibus:                      225.261   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23950.438
# Skew:                           7.166   Prob(JB):                         0.00
# Kurtosis:                      66.659   Cond. No.                     1.33e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### R2 went down
#
# ## Now dropping CDMX

# %%
#Independent variable is area for 2010, dependent on motorization rate, family size, income and subsidies
moto2010s = moto2010.drop([19])
rem2009s = rem2009.drop([19])

d = {'area2010': area2010s, 'moto2010': moto2010s, 'fam2010': fam2010s, 'rem2009': rem2009s, 'sub2010': sub2010s}
# Run regression and print summary
mod3 = smf.ols(formula='area2010 ~ moto2010 + fam2010 + rem2009 + sub2010', data = d).fit()
print(mod3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               area2010   R-squared:                       0.210
# Model:                            OLS   Adj. R-squared:                  0.185
# Method:                 Least Squares   F-statistic:                     8.500
# Date:                Thu, 05 May 2016   Prob (F-statistic):           4.09e-06
# Time:                        10:43:54   Log-Likelihood:                -1392.9
# No. Observations:                 133   AIC:                             2796.
# Df Residuals:                     128   BIC:                             2810.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   3493.9727   2438.708      1.433      0.154     -1331.429  8319.374
# moto2010      -7.7846      2.972     -2.619      0.010       -13.665    -1.904
# fam2010       -0.6596      3.682     -0.179      0.858        -7.945     6.626
# rem2009       64.0488     25.928      2.470      0.015        12.746   115.352
# sub2010      6.56e-05   1.81e-05      3.621      0.000      2.98e-05     0.000
# ==============================================================================
# Omnibus:                      151.546   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3066.256
# Skew:                           4.266   Prob(JB):                         0.00
# Kurtosis:                      24.921   Cond. No.                     1.57e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.57e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
mod3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               area2010   R-squared:                       0.210
# Model:                            OLS   Adj. R-squared:                  0.185
# Method:                 Least Squares   F-statistic:                     8.500
# Date:                Thu, 05 May 2016   Prob (F-statistic):           4.09e-06
# Time:                        10:43:58   Log-Likelihood:                -1392.9
# No. Observations:                 133   AIC:                             2796.
# Df Residuals:                     128   BIC:                             2810.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   3493.9727   2438.708      1.433      0.154     -1331.429  8319.374
# moto2010      -7.7846      2.972     -2.619      0.010       -13.665    -1.904
# fam2010       -0.6596      3.682     -0.179      0.858        -7.945     6.626
# rem2009       64.0488     25.928      2.470      0.015        12.746   115.352
# sub2010      6.56e-05   1.81e-05      3.621      0.000      2.98e-05     0.000
# ==============================================================================
# Omnibus:                      151.546   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3066.256
# Skew:                           4.266   Prob(JB):                         0.00
# Kurtosis:                      24.921   Cond. No.                     1.57e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.57e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Correlations

# %%
np.correlate(area2010s, sub2010new)
# Out:
# array([  3.14077758e+13,   3.41666795e+13])
